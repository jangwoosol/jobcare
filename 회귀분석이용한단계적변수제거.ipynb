# %%
import pandas as pd

def add_code(df, d_code, h_code, l_code):
    df = df.copy()   

    # D Code
    df['person_prefer_d_1_n'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_1_s'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_1_m'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_1_l'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_2_n'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_2_s'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_2_m'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_2_l'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_3_n'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_3_s'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_3_m'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_3_l'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['contents_attribute_d_n'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['contents_attribute_d_s'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['contents_attribute_d_m'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['contents_attribute_d_l'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    # H Code
    df['person_prefer_h_1_m'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    df['person_prefer_h_1_l'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    
    df['person_prefer_h_2_m'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    df['person_prefer_h_2_l'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    
    df['person_prefer_h_3_l'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_3_m'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    df['contents_attribute_h_l'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['contents_attribute_h_m'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    # L Code
    df['contents_attribute_l_n'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 세분류코드'])
    df['contents_attribute_l_s'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 소분류코드'])
    df['contents_attribute_l_m'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 중분류코드'])
    df['contents_attribute_l_l'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 대분류코드'])
    return df

d_code = pd.read_csv('속성_D_코드.csv', index_col=0).T.to_dict()
h_code = pd.read_csv('속성_H_코드.csv', index_col=0).T.to_dict()
l_code = pd.read_csv('속성_L_코드.csv', index_col=0).T.to_dict()

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

df_train = add_code(df_train, d_code, h_code, l_code)
df_test = add_code(df_test, d_code, h_code, l_code)

#형태변환
df_train[['d_l_match_yn','d_m_match_yn','d_s_match_yn','h_l_match_yn','h_m_match_yn','h_s_match_yn']]=df_train[['d_l_match_yn','d_m_match_yn','d_s_match_yn','h_l_match_yn','h_m_match_yn','h_s_match_yn']].astype('int')
df_test[['d_l_match_yn','d_m_match_yn','d_s_match_yn','h_l_match_yn','h_m_match_yn','h_s_match_yn']]=df_test[['d_l_match_yn','d_m_match_yn','d_s_match_yn','h_l_match_yn','h_m_match_yn','h_s_match_yn']].astype('int')
# Out:
# Index(['id', 'd_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
#        'h_m_match_yn', 'h_s_match_yn', 'person_attribute_a',
#        'person_attribute_a_1', 'person_attribute_b', 'person_prefer_c',
#        'person_prefer_d_1', 'person_prefer_d_2', 'person_prefer_d_3',
#        'person_prefer_e', 'person_prefer_f', 'person_prefer_g',
#        'person_prefer_h_1', 'person_prefer_h_2', 'person_prefer_h_3',
#        'contents_attribute_i', 'contents_attribute_a',
#        'contents_attribute_j_1', 'contents_attribute_j',
#        'contents_attribute_c', 'contents_attribute_k', 'contents_attribute_l',
#        'contents_attribute_d', 'contents_attribute_m', 'contents_attribute_e',
#        'contents_attribute_h', 'person_rn', 'contents_rn', 'contents_open_dt',
#        'target', 'person_prefer_d_1_n', 'person_prefer_d_1_s',
#        'person_prefer_d_1_m', 'person_prefer_d_1_l', 'person_prefer_d_2_n',
# ...

# %%
train = pd.read_csv('train.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(25,10))

heat_table = train.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g'], axis=1).corr()
heatmap_ax = sns.heatmap(heat_table, annot=True,cmap='coolwarm')

heatmap_ax.set_xticklabels(heatmap_ax.get_xticklabels(), fontsize=15, rotation=45)
heatmap_ax.set_yticklabels(heatmap_ax.get_yticklabels(), fontsize=15, rotation=45)

plt.title('correlation between features', fontsize=40)
plt.show()

# %%
#명목, 순서형이라 상관계수가 거의 효과가 없다.
heat_table = df_train.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g'], axis=1).corr()
# target과 다른 feature들의 상관계수는 아래와 같습니다.
corr_score = abs(heat_table.target[:-1])

# 상관계수 절대값을 기준으로 오름차순으로 정렬합니다.
corr_score.sort_values()
# Out:
# person_attribute_b        0.003641
# h_m_match_yn              0.004264
# h_s_match_yn              0.006311
# contents_attribute_a      0.008566
# contents_attribute_j_1    0.010707
# contents_attribute_i      0.014837
# person_attribute_a        0.015284
# contents_attribute_m      0.015300
# person_prefer_c           0.016768
# h_l_match_yn              0.018988
# person_prefer_d_3_l       0.021144
# person_attribute_a_1      0.022103
# person_prefer_d_3_m       0.022908
# contents_attribute_l_s    0.023635
# contents_attribute_l_n    0.023698
# contents_attribute_l      0.023740
# contents_attribute_k      0.023783
# person_prefer_d_3_s       0.023886
# person_prefer_d_3         0.023895
# person_prefer_d_3_n       0.023903
# contents_attribute_l_m    0.024426
# contents_attribute_e      0.024869
# person_prefer_d_2_l       0.024936
# person_prefer_d_1_l       0.025102
# person_prefer_d_2_m       0.027035
# person_prefer_d_2_s       0.028247
# person_prefer_d_2_n       0.028485
# ...

# %%
#예측에 필요없는 변수 제거
df_train=df_train.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g'], axis=1)
df_test=df_test.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g'], axis=1)

# %%
# 성능 변화 평가를 위해 data 나누기
x=df_train.drop(['target'],axis=1)
y =df_train['target'] 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=34)

# %%
# 성능 출력 함수
from sklearn.metrics import f1_score

def print_score(predicted, y):
    accuracy = sum(predicted == y) / len(y)*100
    f1 = f1_score(y, predicted)*100
    print(f'accuracy: {accuracy:.2f}%') # 정확도 출력
    print(f'f1_score : {f1:.2f}%') # f1 score 출력
    return accuracy, f1


check_acc = []
check_f1 = []

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()
lg.fit(x_train,y_train)
lg_pred=lg.predict(x_test)
acc,f1=print_score(lg_pred,y_test)
check_acc.append(acc)
check_f1.append(f1)
# Out:
# accuracy: 54.65%
# f1_score : 53.69%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#2단계
x_2train=x_train.drop(['person_attribute_b','h_m_match_yn','h_s_match_yn'],axis=1)
x_2test=x_test.drop(['person_attribute_b','h_m_match_yn','h_s_match_yn'],axis=1)
lg.fit(x_2train,y_train)
lg_2pred=lg.predict(x_2test)
acc,f1=print_score(lg_2pred,y_test)
check_acc.append(acc)
check_f1.append(f1)
# Out:
# accuracy: 54.71%
# f1_score : 53.61%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
x_3train=x_train.drop(['person_attribute_b','h_m_match_yn','h_s_match_yn',
                       'contents_attribute_a','contents_attribute_j_1','contents_attribute_i',
                       'person_attribute_a','contents_attribute_m'],axis=1)
x_3test=x_test.drop(['person_attribute_b','h_m_match_yn','h_s_match_yn',
                       'contents_attribute_a','contents_attribute_j_1','contents_attribute_i',
                       'person_attribute_a','contents_attribute_m'],axis=1)

lg.fit(x_3train,y_train)
lg_3pred=lg.predict(x_3test)
acc,f1=print_score(lg_3pred,y_test)
check_acc.append(acc)
check_f1.append(f1)
# Out:
# accuracy: 54.69%
# f1_score : 53.81%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#sub['target'] = np.where(np.mean(preds, 0)>0.5, 1, 0)
#1,0으로 바꿔주는 것 date_info['holiday_flg2'] = ((date_info['holiday_flg2']>4) | (date_info['holiday_flg']==1)).astype(int)
#명목형 여러개일 때 #x_train['contents_attribute_l_l'].factorize()[0]

# %%
#object 날짜형태로 변환-
df_train['date_time']=pd.to_datetime(df_train['contents_open_dt'])
df_train['month']=df_train.date_time.dt.month
df_train['day']=df_train.date_time.dt.day
df_train['hour']=df_train.date_time.dt.hour
df_train['weekday']=df_train.date_time.dt.dayofweek

df_test['date_time']=pd.to_datetime(df_test['contents_open_dt'])
df_test['month']=df_test.date_time.dt.month
df_test['day']=df_test.date_time.dt.day
df_test['hour']=df_test.date_time.dt.hour
df_test['weekday']=df_test.date_time.dt.dayofweek

# %%
#예측에 필요없는 변수 제거
df_train=df_train.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g','date_time'], axis=1)
df_test=df_test.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g','date_time'], axis=1)

# %%
#new- 예측에 필요없는 변수 제거
df_train=df_train.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g','contents_rn','person_rn'], axis=1)
df_test=df_test.drop(['id','contents_open_dt','person_prefer_f','person_prefer_g','contents_rn','person_rn'], axis=1)

# %%
#선호와 컨텐츠 속성 동일한지 변수생성-A,C
df_train['a_match_yn']=(df_train['person_attribute_a']==df_train['contents_attribute_a']).factorize()[0]
df_train['c_match_yn']=(df_train['person_prefer_c']==df_train['contents_attribute_c']).factorize()[0]
#D대분류 일치코드 속성2,3
df_train['d_l_match_yn2']=(df_train['person_prefer_d_2_l']==df_train['contents_attribute_d_l']).factorize()[0]
df_train['d_l_match_yn3']=(df_train['person_prefer_d_3_l']==df_train['contents_attribute_d_l']).factorize()[0]
#D세분류 일치코드 속성 2,3
df_train['d_m_match_yn2']=(df_train['person_prefer_d_2_n']==df_train['contents_attribute_d_n']).factorize()[0]
df_train['d_m_match_yn3']=(df_train['person_prefer_d_3_n']==df_train['contents_attribute_d_n']).factorize()[0]
#D중분류 일치코드 속성 1,2,3
df_train['d_n_match_yn1']=(df_train['person_prefer_d_1_m']==df_train['contents_attribute_d_m']).factorize()[0]
df_train['d_n_match_yn2']=(df_train['person_prefer_d_2_m']==df_train['contents_attribute_d_m']).factorize()[0]
df_train['d_n_match_yn3']=(df_train['person_prefer_d_3_m']==df_train['contents_attribute_d_m']).factorize()[0]
#D소분류 일치코드 속성 1,2,3
df_train['d_ss_match_yn1']=(df_train['person_prefer_d_1_s']==df_train['contents_attribute_d_s']).factorize()[0]
df_train['d_ss_match_yn2']=(df_train['person_prefer_d_2_s']==df_train['contents_attribute_d_s']).factorize()[0]
df_train['d_ss_match_yn3']=(df_train['person_prefer_d_3_s']==df_train['contents_attribute_d_s']).factorize()[0]
#H대분류 일치코드 속성 2,3
df_train['h_l_match_yn2']=(df_train['person_prefer_h_2_l']==df_train['contents_attribute_h_l']).factorize()[0]
df_train['h_l_match_yn3']=(df_train['person_prefer_h_3_l']==df_train['contents_attribute_h_l']).factorize()[0]
#H중분류 일치코드 속성 2,3
df_train['h_m_match_yn2']=(df_train['person_prefer_h_2_m']==df_train['contents_attribute_h_m']).factorize()[0]
df_train['h_m_match_yn3']=(df_train['person_prefer_h_3_m']==df_train['contents_attribute_h_m']).factorize()[0]
#속성코드 일치 h-2,3/ d-2,3
df_train['d_s_match_yn2']=(df_train['person_prefer_d_2']==df_train['contents_attribute_d']).factorize()[0]
df_train['d_s_match_yn3']=(df_train['person_prefer_d_3']==df_train['contents_attribute_d']).factorize()[0]
df_train['h_s_match_yn2']=(df_train['person_prefer_h_2']==df_train['contents_attribute_h']).factorize()[0]
df_train['h_s_match_yn3']=(df_train['person_prefer_h_3']==df_train['contents_attribute_h']).factorize()[0]

# %%
#선호와 컨텐츠 속성 동일한지 변수생성-A,C
df_test['a_match_yn']=(df_test['person_attribute_a']==df_test['contents_attribute_a']).factorize()[0]
df_test['c_match_yn']=(df_test['person_prefer_c']==df_test['contents_attribute_c']).factorize()[0]
#D대분류 일치코드 속성2,3
df_test['d_l_match_yn2']=(df_test['person_prefer_d_2_l']==df_test['contents_attribute_d_l']).factorize()[0]
df_test['d_l_match_yn3']=(df_test['person_prefer_d_3_l']==df_test['contents_attribute_d_l']).factorize()[0]
#D세분류 일치코드 속성 2,3
df_test['d_m_match_yn2']=(df_test['person_prefer_d_2_n']==df_test['contents_attribute_d_n']).factorize()[0]
df_test['d_m_match_yn3']=(df_test['person_prefer_d_3_n']==df_test['contents_attribute_d_n']).factorize()[0]
#D중분류 일치코드 속성 1,2,3
df_test['d_n_match_yn1']=(df_test['person_prefer_d_1_m']==df_test['contents_attribute_d_m']).factorize()[0]
df_test['d_n_match_yn2']=(df_test['person_prefer_d_2_m']==df_test['contents_attribute_d_m']).factorize()[0]
df_test['d_n_match_yn3']=(df_test['person_prefer_d_3_m']==df_test['contents_attribute_d_m']).factorize()[0]
#D소분류 일치코드 속성 1,2,3
df_test['d_ss_match_yn1']=(df_test['person_prefer_d_1_s']==df_test['contents_attribute_d_s']).factorize()[0]
df_test['d_ss_match_yn2']=(df_test['person_prefer_d_2_s']==df_test['contents_attribute_d_s']).factorize()[0]
df_test['d_ss_match_yn3']=(df_test['person_prefer_d_3_s']==df_test['contents_attribute_d_s']).factorize()[0]
#H대분류 일치코드 속성 2,3
df_test['h_l_match_yn2']=(df_test['person_prefer_h_2_l']==df_test['contents_attribute_h_l']).factorize()[0]
df_test['h_l_match_yn3']=(df_test['person_prefer_h_3_l']==df_test['contents_attribute_h_l']).factorize()[0]
#H중분류 일치코드 속성 2,3
df_test['h_m_match_yn2']=(df_test['person_prefer_h_2_m']==df_test['contents_attribute_h_m']).factorize()[0]
df_test['h_m_match_yn3']=(df_test['person_prefer_h_3_m']==df_test['contents_attribute_h_m']).factorize()[0]
#속성코드 일치 h-2,3/ d-2,3
df_test['d_s_match_yn2']=(df_test['person_prefer_d_2']==df_test['contents_attribute_d']).factorize()[0]
df_test['d_s_match_yn3']=(df_test['person_prefer_d_3']==df_test['contents_attribute_d']).factorize()[0]
df_test['h_s_match_yn2']=(df_test['person_prefer_h_2']==df_test['contents_attribute_h']).factorize()[0]
df_test['h_s_match_yn3']=(df_test['person_prefer_h_3']==df_test['contents_attribute_h']).factorize()[0]

# %%
#'h_l_match_yn'는 회원선호속성과 컨텐츠속성 H 1번 일치 여부- 대분류
#h_m_match_yn'는 회원선호속성과 컨텐츠속성 H 1번 일치 여부- 중분류
#h_s_match_yn'는 h_m_match_yn',h_l_match_yn'둘 다 1일 때
#d_l_match_yn'는 회원선호속성과 컨텐츠속성 H 1번 일치 여부- 대분류
#d_m_match_yn'는 회원선호속성과 컨텐츠속성 H 1번 일치 여부- 세분류
#d_s_match_yn'는 회원선호속성과 컨텐츠속성 H 1번 일치 여부- 분류x

#2번 일치여부, 3번 일치여부 h 1,2,3일치여부

# %%
# 성능 변화 평가를 위해 data 나누기 0.001%로 올라갔다.
x=df_train.drop(['target'],axis=1)
y =df_train['target'] 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=34)

# %%
#랜포로 변수중요도 확인
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
fold=KFold(n_splits=5,shuffle=True, random_state=1)
params={'n_estimators':[100],'max_depth':[3,6,8,10],'min_samples_leaf':[8,12,18],'min_samples_split':[8,16,20]}
rf=RandomForestClassifier(random_state=1, n_jobs=-1)
grid=GridSearchCV(rf,param_grid=params,cv=fold, n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=RandomForestClassifier(n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'max_depth': [3, 6, 8, 10],
#                          'min_samples_leaf': [8, 12, 18],
#                          'min_samples_split': [8, 16, 20],
#                          'n_estimators': [100]})

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=8, min_samples_split=8,
#                        n_jobs=-1, random_state=1)

# %%
pred=grid.predict(x_test)
f1_score(pred,y_test)
# Out:
# 0.6193437509945577

# %%
#new
rf_clf=RandomForestClassifier(n_estimators=300,max_depth=10, min_samples_leaf=8, min_samples_split=8,
                       n_jobs=-1, random_state=1)
rf_clf.fit(x_train,y_train)
pred=rf_clf.predict(x_test)

# %%
print(f1_score(pred,y_test))
#new
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
value=rf_clf.feature_importances_
importance=pd.Series(value, index=x_train.columns)
top20=importance.sort_values(ascending=False)[:20]

plt.figure(figsize=(6,8))
plt.title('features top 20')
sns.barplot(x=top20, y=top20.index)
plt.show()
# Out:
# 0.620092114303163

# %% [markdown]
# ## 그림으로 확인

# %%
rf_clf=RandomForestClassifier(n_estimators=300,max_depth=10, min_samples_leaf=8, min_samples_split=8,
                       n_jobs=-1, random_state=1)
rf_clf.fit(x_train,y_train)
pred=rf_clf.predict(x_test)
acc,f1=print_score(pred,y_test)
check_acc.append(acc)
check_f1.append(f1)
# Out:
# accuracy: 60.33%
# f1_score : 62.01%

# %%
#제출 값 0.65 
y_pred=grid.predict(df_test)
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['target'] = y_pred
sample_submission.to_csv("predictionrf변수추가.csv", index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
value=rf_clf.feature_importances_
importance=pd.Series(value, index=x_train.columns)
top20=importance.sort_values(ascending=False)[:20]

plt.figure(figsize=(6,8))
plt.title('features top 20')
sns.barplot(x=top20, y=top20.index)
plt.show()

# %%
#lightgbm으로 변수중요도 확인
! pip install lightgbm
from lightgbm import LGBMClassifier

import numpy as np
lgbm=LGBMClassifier(n_estimators=300)
#조기 중단
evals=[(x_test,y_test)]
lgbm.fit(x_train,y_train, early_stopping_rounds=100, eval_metric='logloss',eval_set=evals, verbose=True)
preds=lgbm.predict(x_test)
acc,f1=print_score(preds,y_test)
check_acc.append(acc)
check_f1.append(f1)
# Out:
# ...
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.688187
# [2]	valid_0's binary_logloss: 0.684029
# [3]	valid_0's binary_logloss: 0.680536
# [4]	valid_0's binary_logloss: 0.677679
# [5]	valid_0's binary_logloss: 0.675215
# [6]	valid_0's binary_logloss: 0.673117
# [7]	valid_0's binary_logloss: 0.671289
# ...

# %%
from lightgbm import plot_importance
fig, ax= plt.subplots(figsize=(10,12))
plot_importance(lgbm,ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
#new-날짜랑 contents,person_rn 빼고
from lightgbm import LGBMClassifier

import numpy as np
lgbm=LGBMClassifier(n_estimators=300)
#조기 중단
evals=[(x_test,y_test)]
lgbm.fit(x_train,y_train, early_stopping_rounds=100, eval_metric='logloss',eval_set=evals, verbose=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.688187
# [2]	valid_0's binary_logloss: 0.684027
# [3]	valid_0's binary_logloss: 0.680532
# [4]	valid_0's binary_logloss: 0.677686
# [5]	valid_0's binary_logloss: 0.675224
# [6]	valid_0's binary_logloss: 0.673156
# [7]	valid_0's binary_logloss: 0.67134
# ...

# %%
#new
from sklearn.metrics import f1_score
preds=lgbm.predict(x_test)
f1_score(preds,y_test)
# Out:
# 0.6447770965264575

# %%
y_pred=lgbm.predict(df_test)
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['target'] = y_pred
sample_submission.to_csv("predict변수추가.csv", index=False)

# %%
sns.catplot(x='person_attribute_b', y='target', kind="bar",col = "person_attribute_a_1", data=df_train, palette='pastel')

# %%
df_train['target'][(df_train.person_prefer_c==3)&(df_train.person_attribute_b==0)].value_counts()
# Out:
# 1    7
# Name: target, dtype: int64

# %% [markdown]
# 범주형 변수가 많은 범주를 갖고 있고 이 변수는 많은 더미변수로 바뀌어진다.
# 이것은 비록 원래에는 매우 적은 수의 범주형 변수를 갖는다 할지라도 더미변수로 바꾸면
# 데이터 집합의 차원이 매우 커질 수 있다는 것을 뜻한다.따라서 가까운 범주들을 하나로 합침으로써 범주의 수를 줄인다.

# %%
train_data=df_train.copy()
b_direction={0:0,1:0,2:0,3:1,4:2,5:2}
train_data['person_b']=train_data['person_attribute_b'].map(b_direction)

c_direction={1:1,2:1,3:1,4:4,5:4}
train_data['person_c']=train_data['person_prefer_c'].map(c_direction)

e_direction={0:0,1:0,2:0,3:1,4:2,5:3,6:4,7:4,8:4,9:4,10:4,11:4}
train_data['person_e']=train_data['person_prefer_e'].map(e_direction)

j_direction={1:1,2:1,3:1,4:2,5:3,6:3,8:3,9:3,10:3}
train_data['content_j']=train_data['contents_attribute_j_1'].map(j_direction)

c_direction={1:1,2:1,3:2,4:2,5:2}
train_data['content_c']=train_data['contents_attribute_c'].map(c_direction)

test_data=df_test.copy()
test_data['person_b']=test_data['person_attribute_b'].map(b_direction)

test_data['person_c']=test_data['person_prefer_c'].map(c_direction)

test_data['person_e']=test_data['person_prefer_e'].map(e_direction)

test_data['content_j']=test_data['contents_attribute_j_1'].map(j_direction)

test_data['content_c']=test_data['contents_attribute_c'].map(c_direction)

# %% [markdown]
# person_attribute_a_1 순서형 0~7
# person_attribute_b 순서형 0~5
# person_prefer_c 명목형 1~5
# 속성 d,h,l 명목형
# person_prefer_e 순서형 0~11
# contents_attribute_j_1 명목형 1~10
# contents_attribute_c 명목형 1~5
# contents_attribute_m 명목형 1~5
# contents_attribute_e 순서형 0~11

# %%
train_data=train_data.drop(['person_attribute_b','person_prefer_c','person_prefer_e','contents_attribute_j_1','contents_attribute_c'],axis=1)
test_data=test_data.drop(['person_attribute_b','person_prefer_c','person_prefer_e','contents_attribute_j_1', 'contents_attribute_c'],axis=1)

# %%
# 성능 변화 평가를 위해 data 나누기
x=train_data.drop(['target'],axis=1)
y =train_data['target'] 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=34)
#new-날짜랑 contents,person_rn 빼고
from lightgbm import LGBMClassifier

import numpy as np
lgbm=LGBMClassifier(n_estimators=300)
#조기 중단
evals=[(x_test,y_test)]
lgbm.fit(x_train,y_train, early_stopping_rounds=100, eval_metric='logloss',eval_set=evals, verbose=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.688156
# [2]	valid_0's binary_logloss: 0.684014
# [3]	valid_0's binary_logloss: 0.680595
# [4]	valid_0's binary_logloss: 0.677703
# [5]	valid_0's binary_logloss: 0.675263
# [6]	valid_0's binary_logloss: 0.673156
# [7]	valid_0's binary_logloss: 0.671279
# ...

# %%
pred=lgbm.predict(x_test)
f1_score(pred,y_test)
# Out:
# 0.6453296116077603

# %%
from lightgbm import plot_importance
fig, ax= plt.subplots(figsize=(10,12))
plot_importance(lgbm,ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
y_pred=lgbm.predict(test_data)
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['target'] = y_pred
sample_submission.to_csv("lightsum.csv", index=False)

# %%
f, ax = plt.subplots(1, 2, figsize = (8, 8))

x = 'person_prefer_d_1'
y = 'target'

sns.countplot('person_prefer_d_1', hue = 'target', data = df_train, ax = ax[0])

sns.histplot(df_train,
            x = "person_prefer_d_1",
            hue="target",
            multiple="stack", 
            palette="pastel",
            edgecolor=".10",
            linewidth=".20",
            bins = 2,
            ax = ax[1])

plt.tight_layout(h_pad = 2.5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 이진 범주형 특성에서 분산낮은 특성 삭제하기

# %%
step1=df_train.copy()
step1=step1[['person_attribute_a','contents_attribute_j']]
from sklearn.feature_selection import VarianceThreshold
thresholder=VarianceThreshold(threshold=(.75*(1-0.75)))
thresholder.fit_transform(step1)
# Out:
# array([[1],
#        [1],
#        [2],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int64)

# %%
thresholder.variances_
# Out:
# array([0.22441763, 0.18125435])

# %%
import numpy as np
np.var(step1,axis=0)
# Out:
# 0.22441763055512584

# %%
#카이제곱 통계로 두 범주형 벡터의 독립성을 평가한다. 두 범주형 벡터 사이에서만 계산할 수 있다. 타깃벡터와
#특성이 범주형이어야한다, 또한 모든 값이 음수가 아니여야한다.
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
chi2_selector=SelectKBest(chi2,k=20) #변수 개수 줄이기 
chi2_selector.fit(x_train,y_train)
x_select=chi2_selector.transform(x_train)
y_select=chi2_selector.transform(df_test)
xx_select=chi2_selector.transform(x_test)

# %%
lgbm.fit(x_select,y_train)
# Out:
# LGBMClassifier(n_estimators=300)

# %%
#점수baseline보다 안좋아
pre=lgbm.predict(xx_select)
f1_score(pre,y_test)
# Out:
# 0.6306030283161654
